# %% [markdown]
# ### Import Dependencies

# %%
import import_files as MrtRecommendationDependencies
from ridership_cleaner import RidershipCleaner
from ridership_transformer import RidershipTransformer
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# ### Instantiate Cleaner

# %%
### path to this file https://drive.google.com/file/d/1rLFQtvKE1jSQr6Cgd6QeRNmtJgLhWjLH/view?usp=sharing
cleaner = RidershipCleaner("~/Downloads/test.xlsx")

# %% [markdown]
# ### Specify Months to be cleaned

# %%
months = ["january", "february", "march", "april", "may", "june", "july", "august", "september", "october", "november", "december"]

# %%
### pass save_csv=True if you want to save the dataset
### Path will be printed
cleaned_df = cleaner.clean_months("cubao",months)

# %%
transformer = RidershipTransformer(cleaned_df)

# %%
transformed_df = transformer.transform()

# %%
transformed_df.head()
# Out:
#              datetime  entry  exit
# 1 2019-01-01 04:00:00      0     0
# 2 2019-01-01 05:00:00      0     0
# 3 2019-01-01 06:00:00    239    22
# 4 2019-01-01 07:00:00    413   525
# 5 2019-01-01 08:00:00    454   627

# %% [markdown]
# ### Analyze Entry Pattern

# %%
entry_df = transformed_df.drop('exit', axis=1)

# %%
entry_df.set_index('datetime', inplace=True)

# %%
entry_df.plot(figsize=(15, 6))
plt.show()
